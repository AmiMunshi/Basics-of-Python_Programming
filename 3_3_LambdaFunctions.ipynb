# %% [markdown]
# Lambda Functions<br>
#
# A lambda function is a small anonymous function.
#
# A lambda function can take any number of arguments, but can only have one expression.
#
# They do not use def of return key words. These are implicit in lambda

# %%
#Function to find cube of a number
def cube(x):
  return x**3

# %%
x= int(input("Enter the number: "))
print("Cube of the number {} is {}".format(x,cube(x)))
# Out:
# Enter the number: 6
# Cube of the number 6 is 216

# %%
#lambda function to find cube of a number

cube_new= lambda y: y**3

# %%
print(cube_new(6))
# Out:
# 216

# %%
# Function with two values passed in

def add_num(x,y):
  return x+y

# %%
a,b= input("Enter two integers separated by comma ").split(",") #Take the input form the user
print(add_num(int(a),int(b)))
# Out:
# Enter two integers separated by comma 6, -8
# -2

# %%
#Lambda function with two variables

add_new= lambda x,y: x+y

# %%
print(add_new(6,-8))
# Out:
# -2

# %%
#Function to find max of two numbers

def max_num(x,y):
  if x>y:
    return x
  else:
    return y

# %%
a,b= input("Enter two integers separated by comma ").split(",")
print(max_num(int(a), int(b)))
# Out:
# Enter two integers separated by comma 6, -9
# 6

# %%
#Print max of two numbers using lambda function

max_new= lambda x,y: x if x>y else y

# %%
max_new(6,-9)
# Out:
# 6
