# %% [markdown]
# reduce()
# This function  implements a mathematical technique called folding or reduction. <br>
# It is useful when you need to apply a function to an iterable and reduce it to a single cumulative value
#
# Note reduce is a function in functools package. So import it from functool

# %%
#Multiply all the numbers in the list to obtain the final product
from functools import reduce

lst1= list(range(1,5))
reduce(lambda x,y:x*y, lst1)
# Out:
# 24

# %%
#Sum all the nos in the list
from functools import reduce
lst2= [int(a) for a in input().split()] #using list comprehension to take the list of nos from the user
sumNos= lambda a,b: a+b #Function to add two nos
#list3= list(map(sumNos,lst2))
print(lst2)
#print(list3)
sumList= reduce(sumNos, lst2) #Using reduce() to obtain sum of all the nos in the list
# Out:
# 1 4 6 7
# [1, 4, 6, 7]

# %%
print(sumList)
# Out:
# 18

# %%
print(sum(lst2)) #Verifying using sum()
# Out:
# 31

# %%
# using reduce to compute maximum element from list
from functools import reduce
list1=[1,3,6,2,7]
print("The maximum element of the list is : ", end="")
print(reduce(lambda a, b: a if a > b else b, list1))
# Out:
# The maximum element of the list is : 7

# %%
#Find minimum number in the list using reduce

# %%
#WAP to find perimeter of the given quadrilateral when the lengths of each side is given

# %% [markdown]
# zip()
# Python’s zip() function is defined as zip(*iterables). The function takes in iterables as arguments and returns an iterator. This iterator generates a series of tuples containing elements from each iterable. zip() can accept any type of iterable, such as files, lists, tuples, dictionaries, sets, and so on

# %%
#Put student_name, marks and standard in a tuple

name= ["A", "B", "C"]
marks= [24, 23, 26]
std= [5,6,3]

student= list(zip(name, marks, std))
print(student)
# Out:
# [('A', 24, 5), ('B', 23, 6), ('C', 26, 3)]

# %% [markdown]
# enumerate()
# The enumerate() method adds a counter to an iterable and returns it (the enumerate object).
# The firstindex value will start from 0. You can also specify the startindex by using the optional parameter startIndex in enumerate.

# %%
#Enumerate example
languages = ["Hindi", "English", "Sanskrit"]

enum_language= enumerate(languages)

print(list(enum_language))
# Out:
# [(0, 'Hindi'), (1, 'English'), (2, 'Sanskrit')]

# %%
#Use enumerate
x = ('apple', 'banana', 'cherry')

# %%
# enumerate function in loops
l1 = ["high", "medium", "low"]

# printing the tuples in object directly
for ele in enumerate(l1,100):
    print (ele)
# Out:
# (100, 'high')
# (101, 'medium')
# (102, 'low')
